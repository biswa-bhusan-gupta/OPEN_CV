# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Full_Image=cv2.imread('Sammy.jpg')
Full_image=cv2.cvtColor(Full_Image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(Full_Image)

# %%
Height,Width,Channel=Full_Image.shape
Height,Width,Channel
# Out:
# (1367, 1025, 3)

# %%
Face_Image=cv2.imread('Sammy_Face.jpg')
Face_Image=cv2.cvtColor(Face_Image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(Face_Image)

# %%
Face_Image.shape
# Out:
# (375, 486, 3)

# %%
Height,Width,Channel=Face_Image.shape
Height,Width,Channel
# Out:
# (375, 486, 3)

# %%
Full_Image.shape
# Out:
# (1367, 1025, 3)

# %%
sum([1,2,3])
# Out:
# 6

# %%
My_String='sum'

# %%
eval(My_String)
# Out:
# <function sum(iterable, start=0, /)>

# %%
Func=eval('sum')
Func
# Out:
# <function sum(iterable, start=0, /)>

# %%
Func([1,2,3])
# Out:
# 6

# %%
# Now we are using String,Later we will use eval() Function to convert into Function
Methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR','cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
for i in Methods:
    # Create a Copy of the Full Image:
    Full_Image_Copy=Full_Image.copy()
    # Convert String into Function:
    Method=eval(i)
    # Apply Template Matching with the Method:
    Res=cv2.matchTemplate(Full_Image_Copy,Face_Image,Method)
    # Grab Min,Max Values and Locations:
    Min_Value,Max_Value,Min_Loc,Max_Loc=cv2.minMaxLoc(Res)
    
    # If the Method is TM_SQDIFF or TM_SQDIFF_NORMED,Take Minimum:
    if Method in [cv2.TM_SQDIFF,cv2.TM_SQDIFF_NORMED]:
        Top_Left=Min_Loc #(x,y)
    else:
        Top_Left=Max_Loc
        
    Height,Width,Channel=Face_Image.shape
    # Refer to Notebook:
    Bottom_Right=(Top_Left[0]+Width,Top_Left[1]+Height)
    cv2.rectangle(Full_Image_Copy,Top_Left,Bottom_Right,color=(0,255,0),thickness=20)
    
    # One Row Two Coumn,End 1 is Grab First Image 
    plt.subplot(121)
    plt.imshow(Res)
    plt.title('HEATMAP OF TEMPLATE MATCHING:')
    
    # One Row Two Coumn,End 1 is Grab Second Image
    plt.subplot(122)
    plt.imshow(Full_Image_Copy)
    plt.title('DETECTION OF TEMPLATE:')
    
    #Title with Method Used:
    plt.suptitle(i)
    
    plt.show()
    
    print('\n')
    print('\n')

# %%
Top_Left[0],Top_Left[1]
# Out:
# (231, 345)

# %%
Width,Height
# Out:
# (486, 375)

# %%
Method
# Out:
# 1

# %%
Min_Value,Max_Value
# Out:
# (0.028285279870033264, 1.0)

# %%
Min_Loc,Max_Loc
# Out:
# ((231, 345), (0, 0))

# %%
Res
# Out:
# array([[1.        , 1.        , 1.        , ..., 0.7857801 , 0.78654677,
#         0.78706545],
#        [1.        , 1.        , 1.        , ..., 0.78565496, 0.7862843 ,
#         0.7867794 ],
#        [1.        , 1.        , 1.        , ..., 0.7856476 , 0.786176  ,
#         0.78653896],
#        ...,
#        [0.591992  , 0.592813  , 0.59319645, ..., 0.7389159 , 0.7382845 ,
#         0.73748904],
#        [0.5920231 , 0.59276664, 0.59307396, ..., 0.7390499 , 0.7385437 ,
#         0.73776287],
#        [0.59163266, 0.5922797 , 0.5926688 , ..., 0.7392072 , 0.7388025 ,
#         0.7381074 ]], dtype=float32)

# %%
My_Method=eval('cv2.TM_CCOEFF')
Res=cv2.matchTemplate(Full_Image_Copy,Face_Image,My_Method)
plt.imshow(Res)

# %%
My_Method=eval('cv2.TM_CCOEFF_NORMED')
Res=cv2.matchTemplate(Full_Image_Copy,Face_Image,My_Method)
plt.imshow(Res)

# %%
My_Method=eval('cv2.TM_CCORR')
Res=cv2.matchTemplate(Full_Image_Copy,Face_Image,My_Method)
plt.imshow(Res)

# %%
My_Method=eval('cv2.TM_CCORR_NORMED')
Res=cv2.matchTemplate(Full_Image_Copy,Face_Image,My_Method)
plt.imshow(Res)

# %%
My_Method=eval('cv2.TM_SQDIFF')
Res=cv2.matchTemplate(Full_Image_Copy,Face_Image,My_Method)
plt.imshow(Res)

# %%
My_Method=eval('cv2.TM_SQDIFF_NORMED')
Res=cv2.matchTemplate(Full_Image_Copy,Face_Image,My_Method)
plt.imshow(Res)
