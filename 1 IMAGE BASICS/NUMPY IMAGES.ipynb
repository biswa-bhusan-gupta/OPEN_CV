# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
Image=Image.open('Cat or Dog.jpg')

# %%
Image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=235x175 at 0x2698E8CA188>

# %%
type(Image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
Image_Array=np.asarray(Image)

# %%
Image_Array
# Out:
# array([[[ 26,  26,  26],
#         [ 16,  16,  16],
#         [  5,   5,   5],
#         ...,
#         [197, 104, 161],
#         [197, 104, 161],
#         [199, 104, 162]],
#
#        [[ 17,  17,  17],
#         [ 10,  10,  10],
#         [  1,   1,   1],
#         ...,
#         [196, 105, 162],
#         [198, 105, 162],
#         [198, 105, 162]],
#
#        [[  7,   7,   7],
#         [  2,   2,   2],
#         [  0,   0,   0],
#         ...,
#         [187,  98, 154],
#         [187,  98, 154],
#         [188,  97, 154]],
#
#        ...,
#
#        [[ 95,  70,  91],
#         [ 97,  68,  90],
#         [113,  78, 102],
#         ...,
#         [ 44,  27,  43],
#         [ 34,  16,  30],
#         [ 23,   5,  17]],
#
#        [[ 67,  53,  70],
#         [ 74,  55,  74],
#         [ 96,  71,  92],
#         ...,
#         [ 26,   9,  25],
#         [ 18,   0,  14],
#         [ 11,   0,   5]],
#
#        [[ 44,  36,  51],
#         [ 58,  45,  62],
#         [ 87,  66,  85],
# ...

# %%
Image_Array.shape
# Out:
# (175, 235, 3)

# %%
type(Image_Array)
# Out:
# numpy.ndarray

# %%
plt.imshow(Image_Array)

# %%
plt.imshow(Image)

# %% [markdown]
# ## R G B : 0 1 2

# %%
Image_Array.shape
# Out:
# (175, 235, 3)

# %%
Image_Red=Image_Array.copy()
plt.imshow(Image_Red[:,:,0])

# %%
Image_Blue=Image_Array.copy()
plt.imshow(Image_Blue[:,:,1])

# %%
Image_Green=Image_Array.copy()
plt.imshow(Image_Green[:,:,2])

# %%
# Red Channel:
# 0: No Red,255: Full Red
plt.imshow(Image_Red[:,:,0],cmap='gray') # More Red

# %%
# Green Channel:
plt.imshow(Image_Green[:,:,1],cmap='gray')

# %%
# Blue Channel:
plt.imshow(Image_Blue[:,:,2],cmap='gray')

# %%
Image_Green[:,:,1]=0
plt.imshow(Image_Green)

# %%
Image_Red[:,:,0]=0
plt.imshow(Image_Red)

# %%
Image_Blue[:,:,2]=0
plt.imshow(Image_Blue)

# %%
Image_Blue.shape
# Out:
# (175, 235, 3)

# %%
Image_Blue[:,:,2].shape
# Out:
# (175, 235)

# %%
Image_Copy=Image_Array.copy()
Image_Copy[:,:,0]=0 # No Red
Image_Copy[:,:,1]=0 # No Green
plt.imshow(Image_Copy)
